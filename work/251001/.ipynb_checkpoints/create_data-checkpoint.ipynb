# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from create_data import create_data

# %%
cr = create_data()

# %%
tm_df = cr.tmsdata()

# %%
df = cr.tmsdata()
print(df.head(3))
df.info()
daily = df.groupby('date').agg({'revenue': 'sum', 'cost': 'sum'})
daily['margin'] = daily['revenue'] - daily['cost']
print(daily.head(3))
daily['rev_ma7'] = daily['margin'].rolling(7).mean();
# Out:
#          date channel campaign    segment   device   region  impressions  \
# 0  2024-01-01   Email     EM-6        New  Desktop    Daegu         1128
# 1  2024-01-01   Email     EM-4  Returning   Mobile    Seoul         1069
# 2  2024-01-01     SMS     SM-5        New   Mobile  Incheon         1032
#
#    clicks  cost  conversions  revenue       ctr       cvr       cpc       cac  \
# 0     103  3.38            3   163.94  0.091312  0.029126  0.032816  1.126667
# 1      86  3.21            2    86.08  0.080449  0.023256  0.037326  1.605000
# 2      94  3.10            6   262.18  0.091085  0.063830  0.032979  0.516667
#
#         roas
# 0  48.502959
# 1  26.816199
# 2  84.574194
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1820 entries, 0 to 1819
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1820 non-null   object
#  1   channel      1820 non-null   object
#  2   campaign     1820 non-null   object
#  3   segment      1820 non-null   object
#  4   device       1820 non-null   object
#  5   region       1820 non-null   object
#  6   impressions  1820 non-null   int64
#  7   clicks       1820 non-null   int64
#  8   cost         1820 non-null   float64
#  9   conversions  1820 non-null   int64
#  10  revenue      1820 non-null   float64
#  11  ctr          1820 non-null   float64
#  12  cvr          1820 non-null   float64
#  13  cpc          1820 non-null   float64
#  14  cac          1820 non-null   float64
#  15  roas         1820 non-null   float64
# dtypes: float64(7), int64(3), object(6)
# memory usage: 227.6+ KB
#             revenue    cost   margin
# date
# 2024-01-01  3127.19  257.13  2870.06
# 2024-01-02  4028.37  265.73  3762.64
# 2024-01-03  3680.75  267.66  3413.09

# %%
plt.figure()
plt.plot(daily['revenue'])
plt.plot(daily['rev_ma7'])
plt.savefig('daily_revenue_ma.png')
plt.show()
plt.close()

# %%
ctr_channel = df.groupby('channel').agg({'clicks': 'sum', 'impressions': 'sum'})
print(ctr_channel.head(3))
ctr_channel['ctr'] = ctr_channel['clicks']/ctr_channel['impressions']

plt.figure();
plt.bar(ctr_channel.index.values, ctr_channel.ctr)
plt.title("CTR by channel")
plt.savefig('ctr_channel.png')
plt.show()
plt.close()
# Out:
#          clicks  impressions
# channel
# Ads       62253      2078733
# Email     43124       479629
# Push      41248       519648

# %%
import seaborn as sns
agg = df.groupby(['channel', 'campaign']).agg({'impressions': 'sum', 'revenue': 'sum', 'cost': 'sum'})

# %%
plt.figure()
plt.scatter(agg['cost'], agg['revenue'])
plt.tight_layout()
plt.savefig('plt_scatter.png')
plt.show()
plt.close()

agg.reset_index(inplace=True)

plt.figure()
sns.pairplot(agg, vars = ['impressions', 'revenue', 'cost'], hue='channel', diag_kind='kde')
plt.savefig('sns_pairplot.png')
plt.show()
plt.close()

# %%
plt.figure()
metrics = df[['impressions', 'clicks', 'revenue', 'cost', 'ctr']]
corr = metrics.corr()
sns.heatmap(corr, annot=True, fmt='g', cmap='YlGnBu')
plt.savefig('corr_heatmap.png')
plt.show()
plt.close()

# %%
cat_df = cr.catdata()
print(cat_df.head(10))
# Out:
#         date channel    segment   device   region response
# 0 2024-05-18   Email        New   Mobile  Gwangju      Yes
# 1 2024-06-08    Push  Returning   Mobile  Incheon       No
# 2 2024-04-26     SMS  Returning   Mobile  Incheon       No
# 3 2024-07-28   Email        New   Mobile  Daejeon       No
# 4 2024-06-07     SMS        New   Mobile  Daejeon       No
# 5 2024-06-23     Ads  Returning   Mobile    Seoul      Yes
# 6 2024-04-24    Push  Returning   Mobile  Incheon      Yes
# 7 2024-07-13     SMS  Returning   Mobile    Seoul       No
# 8 2024-07-02    Push  Returning  Desktop    Seoul       No
# 9 2024-05-28     Ads        New   Mobile  Incheon       No

# %%
plt.figure()
ax = sns.countplot(cat_df, x='channel', stat='count')
ax.set_title('cat count')

for container in ax.containers:
    ax.bar_label(container, fmt='%d')

plt.savefig('cat_countplot.png')
plt.show()
plt.close()

# %%
plt.figure()
ax = sns.countplot(cat_df, x='channel', hue='segment')
ax.set_title('count by channel * segment')
ax.set_xlabel('channel*segment')
ax.set_ylabel('count')

for container in ax.containers:
    ax.bar_label(container, fmt='%d')

plt.savefig('cat_countplot_hue.png')
plt.show()
plt.close()

# %%
regionorder = df['region'].value_counts().index

# %%
plt.figure()
ax = sns.countplot(order = regionorder, y='region', data=df)
ax.set_xlabel('count')
ax.set_ylabel('region')
for container in ax.containers:
    ax.bar_label(container, fmt='%d')

plt.savefig('region_countplot.png')
plt.show()
plt.close()

# %%
plt.figure()
ax = sns.catplot(kind = 'count',
                data = df,
                x = 'channel',
                hue = 'device',
                col = 'segment',
                col_wrap = 2,
                height = 3.5,
                aspect = 1.2)
ax.set_titles(col_template="{col_name}")

for axis in ax.axes.flat:
      for container in axis.containers:
          axis.bar_label(container, fmt='%d')

plt.savefig('catplot.png')
plt.show()
plt.close()

# %%
import pickle

# %%
new_df = pd.read_pickle('refresh.pkl')
print(new_df.head(3))
# Out:
#                    날짜    서버 비고
# 0 2023-12-21 12:39:00  OM11
# 1 2023-12-21 21:39:00  OM06
# 2 2023-12-22 08:23:00  OM13

# %%
fig, axes = plt.subplots(4,4, figsize=(10,10))

for row in range(4):
   for col in range(4):
       idx  = row*4 + col+1
       server = f"OM{idx:02d}"
       print(server)
       temp_df = new_df.loc[new_df['서버']==server]
       print(temp_df.head(4))
       ax = axes[row, col]
       ax.plot(temp_df.날짜.dt.strftime('%m-%d'), temp_df.index, marker='o', color='red')
       ax.tick_params(axis='x', labelrotation=45)
       ax.grid(True)
       ax.set_title(server)
plt.title('siebel process down')
plt.tight_layout()
plt.show()
# Out:
# OM01
#                     날짜    서버 비고
# 4  2023-12-22 08:56:00  OM01
# 20 2023-12-26 21:40:00  OM01
# 26 2023-12-29 19:46:00  OM01
# 30 2024-01-03 06:51:00  OM01
# OM02
#                     날짜    서버 비고
# 5  2023-12-22 09:48:00  OM02
# 12 2023-12-22 17:52:00  OM02
# 36 2024-01-03 15:57:00  OM02
# 37 2024-01-04 08:55:00  OM02
# OM03
#                     날짜    서버 비고
# 75 2024-01-12 14:47:00  OM03
# 97 2024-01-17 18:23:00  OM03
# OM04
#                     날짜    서버 비고
# 10 2023-12-22 16:46:00  OM04
# OM05
#                     날짜    서버 비고
# 3  2023-12-22 08:28:00  OM05
# 9  2023-12-22 16:45:00  OM05
# 15 2023-12-26 18:22:00  OM05
# 22 2023-12-29 18:50:00  OM05
# OM06
#                     날짜    서버 비고
# 1  2023-12-21 21:39:00  OM06
# 13 2023-12-26 10:10:00  OM06
# 17 2023-12-26 19:06:00  OM06
# 24 2023-12-29 19:21:00  OM06
# OM07
#                     날짜    서버 비고
# 73 2024-01-12 14:43:00  OM07
# 84 2024-01-15 17:23:00  OM07
# OM08
# Empty DataFrame
# Columns: [날짜, 서버, 비고]
# Index: []
# OM09
#                     날짜    서버 비고
# 7  2023-12-22 10:31:00  OM09
# 19 2023-12-26 21:35:00  OM09
# 33 2024-01-03 10:06:00  OM09
# 34 2024-01-03 15:56:00  OM09
# OM10
#                     날짜    서버 비고
# 6  2023-12-22 10:18:00  OM10
# 14 2023-12-26 10:11:00  OM10
# 31 2024-01-03 09:09:00  OM10
# 44 2024-01-06 10:34:00  OM10
# OM11
#                    날짜    서버 비고
# 0 2023-12-21 12:39:00  OM11
# OM12
#                     날짜    서버 비고
# 74 2024-01-12 14:45:00  OM12
# OM13
#                     날짜    서버 비고
# 2  2023-12-22 08:23:00  OM13
# 11 2023-12-22 17:03:00  OM13
# 18 2023-12-26 19:36:00  OM13
# 23 2023-12-29 19:15:00  OM13
# OM14
#                     날짜    서버 비고
# 8  2023-12-22 13:06:00  OM14
# 16 2023-12-26 19:00:00  OM14
# 25 2023-12-29 19:27:00  OM14
# 27 2024-01-02 21:08:00  OM14
# OM15
#                     날짜    서버 비고
# 21 2023-12-29 09:14:00  OM15
# 65 2024-01-09 17:10:00  OM15
# OM16
#                     날짜    서버 비고
# 98 2024-01-18 18:15:00  OM16

# %%
camp = { "캠페인 실행": { "가입": 120, "미가입": 380}, "캠페인 미수행": {"가입":80, "미가입": 420} }

# %%
camp_df = pd.DataFrame.from_dict(camp)

# %%
from scipy.stats import chi2_contingency

# %%
chi2, p, dof, expected = chi2_contingency(camp_df)

# %%
print("\n카이제곱 통계량", chi2)
# Out:
# 카이제곱 통계량 9.506250000000001

# %%
print("p-value", p)
# Out:
# p-value 0.002047732153668759

# %%
print("자유도", dof)
# Out:
# 자유도 1

# %%
print("기대빈도료:")
# Out:
# 기대빈도료:

# %%
print(pd.DataFrame(expected, columns=camp_df.columns, index=camp_df.index))
# Out:
#      캠페인 실행  캠페인 미수행
# 가입    100.0    100.0
# 미가입   400.0    400.0
